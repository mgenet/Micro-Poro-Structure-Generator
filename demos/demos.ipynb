# %%
import dolfin
import math
import os

import micro_poro_structure_generator as gen
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 2D

# %% [markdown]
# ### Parallelogram with circular inclusions

# %%
mesh_filename = "mesh-2D_parallelogram_w_circular_inclusions"

gen.generate_mesh_2D_parallelogram_w_circular_inclusions(
    mesh_filename = mesh_filename,
    width = 1.,
    angle = math.pi/3,
    r = 1./10,
    lcar = 1./30,
    shift_x = 0.,
    shift_y = 0.)

mesh = dolfin.Mesh(mesh_filename+".xml")
dolfin.plot(mesh)
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 30%] Meshing curve 5 (Ellipse)
# Info    : [ 40%] Meshing curve 6 (Line)
# Info    : [ 50%] Meshing curve 7 (Ellipse)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Ellipse)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Ellipse)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000762416s, CPU 0.000874s)
# Info    : Meshing 2D...
# Info    : Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0309974s, CPU 0.030738s)
# Info    : 1112 nodes 2140 elements
# Info    : Writing 'mesh-2D_parallelogram_w_circular_inclusions.msh'...
# Info    : Done writing 'mesh-2D_parallelogram_w_circular_inclusions.msh'
# Warning : Gmsh has aleady been initialized
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-2D_parallelogram_w_circular_inclusions.msh -format msh22 mesh-2D_parallelogram_w_circular_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:04 2023
# Info    : Reading 'mesh-2D_parallelogram_w_circular_inclusions.msh'...
# Info    : 26 entities
# Info    : 1019 nodes
# Info    : 1918 elements
# Info    : Done reading 'mesh-2D_parallelogram_w_circular_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.000285209s, CPU 0.000256s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 1.9e-05s, CPU 1.2e-05s)
# Info    : 1025 nodes 1932 elements
# Info    : Writing 'mesh-2D_parallelogram_w_circular_inclusions.msh'...
# Info    : Done writing 'mesh-2D_parallelogram_w_circular_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:04 2023 (From start: Wall 0.00782446s, CPU 0.279915s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 1019 vertices
# Found all vertices
# Expecting 1918 cells
# Found all cells
# Conversion done
# Info    : Writing 'mesh-2D_parallelogram_w_circular_inclusions.vtk'...
# Info    : Done writing 'mesh-2D_parallelogram_w_circular_inclusions.vtk'
# [<matplotlib.lines.Line2D at 0x14cc24fd0>,
#  <matplotlib.lines.Line2D at 0x14cc252d0>]

# %% [markdown]
# ### Rectangle with circular inclusions

# %%
mesh_filename = "mesh-2D_rectangle_w_circular_inclusions"

gen.generate_mesh_2D_rectangle_w_circular_inclusions(
    mesh_filename = mesh_filename,
    width = 1.,
    r = 1./10,
    lcar = 1./30,
    shift_x = 0.,
    shift_y = 0.)

mesh = dolfin.Mesh(mesh_filename+".xml")
dolfin.plot(mesh)
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Ellipse)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Ellipse)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 60%] Meshing curve 6 (Line)
# Info    : [ 70%] Meshing curve 7 (Ellipse)
# Info    : [ 80%] Meshing curve 8 (Line)
# Info    : [ 90%] Meshing curve 9 (Ellipse)
# Info    : Done meshing 1D (Wall 0.000676958s, CPU 0.000751s)
# Info    : Meshing 2D...
# Info    : Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0578287s, CPU 0.057752s)
# Info    : 1902 nodes 3813 elements
# Info    : Writing 'mesh-2D_rectangle_w_circular_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_circular_inclusions.msh'
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-2D_rectangle_w_circular_inclusions.msh -format msh22 mesh-2D_rectangle_w_circular_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:05 2023
# Info    : Reading 'mesh-2D_rectangle_w_circular_inclusions.msh'...
# Info    : 19 entities
# Info    : 1902 nodes
# Info    : 3625 elements
# Info    : Done reading 'mesh-2D_rectangle_w_circular_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.00030825s, CPU 0.000275s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 2.6583e-05s, CPU 1.2e-05s)
# Info    : 1902 nodes 3634 elements
# Info    : Writing 'mesh-2D_rectangle_w_circular_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_circular_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:05 2023 (From start: Wall 0.0127731s, CPU 0.275431s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 1902 vertices
# Found all vertices
# Expecting 3625 cells
# Found all cells
# Conversion done
# Info    : Writing 'mesh-2D_rectangle_w_circular_inclusions.vtk'...
# Info    : Done writing 'mesh-2D_rectangle_w_circular_inclusions.vtk'
# Phis0=0.9643496895459946
# Phif0=0.03565031045400535
# [<matplotlib.lines.Line2D at 0x14cc4ae30>,
#  <matplotlib.lines.Line2D at 0x14cc4b130>]

# %% [markdown]
# ### Square with circular inclusions

# %%
mesh_filename = "mesh-2D_square_w_circular_inclusions"

gen.generate_mesh_2D_square_w_circular_inclusions(
    mesh_filename = mesh_filename,
    width = 1.,
    r = 1./10,
    lcar = 1./30,
    shift_x = 0.,
    shift_y = 0.)

mesh = dolfin.Mesh(mesh_filename+".xml")
dolfin.plot(mesh)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Ellipse)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Ellipse)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Ellipse)
# Info    : [ 70%] Meshing curve 6 (Line)
# Info    : [ 80%] Meshing curve 7 (Ellipse)
# Info    : [ 90%] Meshing curve 8 (Line)
# Info    : Done meshing 1D (Wall 0.000580042s, CPU 0.000706s)
# Info    : Meshing 2D...
# Info    : Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.033385s, CPU 0.034089s)
# Info    : 1111 nodes 2228 elements
# Info    : Writing 'mesh-2D_square_w_circular_inclusions.msh'...
# Info    : Done writing 'mesh-2D_square_w_circular_inclusions.msh'
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-2D_square_w_circular_inclusions.msh -format msh22 mesh-2D_square_w_circular_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:06 2023
# Info    : Reading 'mesh-2D_square_w_circular_inclusions.msh'...
# Info    : 17 entities
# Info    : 1111 nodes
# Info    : 2104 elements
# Info    : Done reading 'mesh-2D_square_w_circular_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.0002925s, CPU 0.000256s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 2.4542e-05s, CPU 1.1e-05s)
# Info    : 1111 nodes 2112 elements
# Info    : Writing 'mesh-2D_square_w_circular_inclusions.msh'...
# Info    : Done writing 'mesh-2D_square_w_circular_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:06 2023 (From start: Wall 0.00858329s, CPU 0.271461s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 1111 vertices
# Found all vertices
# Expecting 2104 cells
# Found all cells
# Conversion done
# Info    : Writing 'mesh-2D_square_w_circular_inclusions.vtk'...
# Info    : Done writing 'mesh-2D_square_w_circular_inclusions.vtk'
# Phis0=0.9690983005625006
# Phif0=0.03090169943749943
# [<matplotlib.lines.Line2D at 0x14ccb9ba0>,
#  <matplotlib.lines.Line2D at 0x14ccb9ea0>]

# %%
mesh_filename = "mesh-2D_square_w_circular_inclusions"

gen.generate_mesh_2D_square_w_circular_inclusions(
    mesh_filename = mesh_filename,
    width = 1.,
    r = 1./10,
    lcar = 1./30,
    shift_x = 0.5,
    shift_y = 0.5)

mesh = dolfin.Mesh(mesh_filename+".xml")
dolfin.plot(mesh)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 40%] Meshing curve 3 (Line)
# Info    : [ 60%] Meshing curve 4 (Line)
# Info    : [ 80%] Meshing curve 5 (Ellipse)
# Info    : Done meshing 1D (Wall 0.000366917s, CPU 0.000606s)
# Info    : Meshing 2D...
# Info    : Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0320616s, CPU 0.031959s)
# Info    : 1114 nodes 2233 elements
# Info    : Writing 'mesh-2D_square_w_circular_inclusions.msh'...
# Info    : Done writing 'mesh-2D_square_w_circular_inclusions.msh'
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-2D_square_w_circular_inclusions.msh -format msh22 mesh-2D_square_w_circular_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:07 2023
# Info    : Reading 'mesh-2D_square_w_circular_inclusions.msh'...
# Info    : 11 entities
# Info    : 1114 nodes
# Info    : 2089 elements
# Info    : Done reading 'mesh-2D_square_w_circular_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.000300333s, CPU 0.00026s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 2.2291e-05s, CPU 1.2e-05s)
# Info    : 1114 nodes 2094 elements
# Info    : Writing 'mesh-2D_square_w_circular_inclusions.msh'...
# Info    : Done writing 'mesh-2D_square_w_circular_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:07 2023 (From start: Wall 0.00872896s, CPU 0.270579s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 1114 vertices
# Found all vertices
# Expecting 2089 cells
# Found all cells
# Conversion done
# Info    : Writing 'mesh-2D_square_w_circular_inclusions.vtk'...
# Info    : Done writing 'mesh-2D_square_w_circular_inclusions.vtk'
# Phis0=0.9691535504255572
# Phif0=0.030846449574442825
# [<matplotlib.lines.Line2D at 0x14cd24c10>,
#  <matplotlib.lines.Line2D at 0x14cd24f10>]

# %% [markdown]
# ### Rectangle with hexagonal inclusions

# %%
mesh_filename = "mesh-2D_rectangle_w_hexagonal_inclusions"

gen.generate_mesh_2D_rectangle_w_hexagonal_inclusions(
    mesh_filename = mesh_filename,
    phi = 0.5,
    R = 0.1,
    lcar = 1./30)

mesh = dolfin.Mesh(mesh_filename+".xml")
dolfin.plot(mesh)
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 13 (Line)
# Info    : [ 10%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Line)
# Info    : [ 20%] Meshing curve 16 (Line)
# Info    : [ 20%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 31 (Line)
# Info    : [ 20%] Meshing curve 32 (Line)
# Info    : [ 20%] Meshing curve 33 (Line)
# Info    : [ 30%] Meshing curve 34 (Line)
# Info    : [ 30%] Meshing curve 35 (Line)
# Info    : [ 30%] Meshing curve 42 (Line)
# Info    : [ 30%] Meshing curve 43 (Line)
# Info    : [ 30%] Meshing curve 44 (Line)
# Info    : [ 30%] Meshing curve 45 (Line)
# Info    : [ 40%] Meshing curve 46 (Line)
# Info    : [ 40%] Meshing curve 60 (Line)
# Info    : [ 40%] Meshing curve 61 (Line)
# Info    : [ 40%] Meshing curve 62 (Line)
# Info    : [ 40%] Meshing curve 63 (Line)
# Info    : [ 40%] Meshing curve 64 (Line)
# Info    : [ 50%] Meshing curve 71 (Line)
# Info    : [ 50%] Meshing curve 72 (Line)
# Info    : [ 50%] Meshing curve 73 (Line)
# Info    : [ 50%] Meshing curve 74 (Line)
# Info    : [ 50%] Meshing curve 75 (Line)
# Info    : [ 50%] Meshing curve 89 (Line)
# Info    : [ 50%] Meshing curve 90 (Line)
# Info    : [ 60%] Meshing curve 91 (Line)
# Info    : [ 60%] Meshing curve 92 (Line)
# Info    : [ 60%] Meshing curve 93 (Line)
# Info    : [ 60%] Meshing curve 100 (Line)
# Info    : [ 60%] Meshing curve 101 (Line)
# Info    : [ 60%] Meshing curve 102 (Line)
# Info    : [ 70%] Meshing curve 103 (Line)
# Info    : [ 70%] Meshing curve 104 (Line)
# Info    : [ 70%] Meshing curve 105 (Line)
# Info    : [ 70%] Meshing curve 106 (Line)
# Info    : [ 70%] Meshing curve 107 (Line)
# Info    : [ 70%] Meshing curve 108 (Line)
# Info    : [ 80%] Meshing curve 109 (Line)
# Info    : [ 80%] Meshing curve 110 (Line)
# Info    : [ 80%] Meshing curve 111 (Line)
# Info    : [ 80%] Meshing curve 112 (Line)
# Info    : [ 80%] Meshing curve 113 (Line)
# Info    : [ 80%] Meshing curve 114 (Line)
# Info    : [ 90%] Meshing curve 115 (Line)
# Info    : [ 90%] Meshing curve 116 (Line)
# Info    : [ 90%] Meshing curve 117 (Line)
# Info    : [ 90%] Meshing curve 118 (Line)
# Info    : [ 90%] Meshing curve 119 (Line)
# Info    : [ 90%] Meshing curve 120 (Line)
# Info    : [100%] Meshing curve 121 (Line)
# Info    : [100%] Meshing curve 122 (Line)
# Info    : [100%] Meshing curve 123 (Line)
# Info    : [100%] Meshing curve 124 (Line)
# Info    : [100%] Meshing curve 125 (Line)
# Info    : [100%] Meshing curve 126 (Line)
# Info    : Done meshing 1D (Wall 0.00416267s, CPU 0.005315s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1000 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0481859s, CPU 0.048063s)
# Info    : 2571 nodes 4171 elements
# Info    : Writing 'mesh-2D_rectangle_w_hexagonal_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_hexagonal_inclusions.msh'
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-2D_rectangle_w_hexagonal_inclusions.msh -format msh22 mesh-2D_rectangle_w_hexagonal_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:08 2023
# Info    : Reading 'mesh-2D_rectangle_w_hexagonal_inclusions.msh'...
# Info    : 156 entities
# Info    : 1540 nodes
# Info    : 2732 elements
# Info    : Done reading 'mesh-2D_rectangle_w_hexagonal_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.000294667s, CPU 0.000265s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 2.0958e-05s, CPU 1.2e-05s)
# Info    : 1611 nodes 2825 elements
# Info    : Writing 'mesh-2D_rectangle_w_hexagonal_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_hexagonal_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:08 2023 (From start: Wall 0.0107381s, CPU 0.271101s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 1540 vertices
# Found all vertices
# Expecting 2732 cells
# Found all cells
# Conversion done
# Info    : Writing 'mesh-2D_rectangle_w_hexagonal_inclusions.vtk'...
# Info    : Done writing 'mesh-2D_rectangle_w_hexagonal_inclusions.vtk'
# [<matplotlib.lines.Line2D at 0x14cd6aec0>,
#  <matplotlib.lines.Line2D at 0x14cd6b1c0>]

# %% [markdown]
# ### Rectangle with Voronoi inclusions

# %%
mesh_filename = "mesh-2D_rectangle_w_voronoi_inclusions"
seeds_filename = "seeds-2D_rectangle_w_voronoi_inclusions"

gen.generate_seeds_random(
    nb_seeds=10,
    seeds_filename=seeds_filename)

gen.generate_mesh_2D_rectangle_w_voronoi_inclusions(
    mesh_filename = mesh_filename,
    seeds_filename = seeds_filename,
    h = 0.04,
    lcar = 0.02,
    domain_x = 1.,
    domain_y = 1.,
    shift_y = 0.,
    remove_seeds = False)

mesh = dolfin.Mesh(mesh_filename+".xml")
dolfin.plot(mesh)
# Out:
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 906 (Line)
# Info    : [ 10%] Meshing curve 907 (Line)
# Info    : [ 10%] Meshing curve 908 (Line)
# Info    : [ 10%] Meshing curve 995 (Line)
# Info    : [ 10%] Meshing curve 996 (Line)
# Info    : [ 10%] Meshing curve 997 (Line)
# Info    : [ 10%] Meshing curve 998 (Line)
# Info    : [ 10%] Meshing curve 999 (Line)
# Info    : [ 10%] Meshing curve 1000 (Line)
# Info    : [ 20%] Meshing curve 1001 (Line)
# Info    : [ 20%] Meshing curve 1002 (Line)
# Info    : [ 20%] Meshing curve 1003 (Line)
# Info    : [ 20%] Meshing curve 1004 (Line)
# Info    : [ 20%] Meshing curve 1005 (Line)
# Info    : [ 20%] Meshing curve 1006 (Line)
# Info    : [ 20%] Meshing curve 1007 (Line)
# Info    : [ 20%] Meshing curve 1008 (Line)
# Info    : [ 20%] Meshing curve 1009 (Line)
# Info    : [ 30%] Meshing curve 1010 (Line)
# Info    : [ 30%] Meshing curve 1011 (Line)
# Info    : [ 30%] Meshing curve 1012 (Line)
# Info    : [ 30%] Meshing curve 1013 (Line)
# Info    : [ 30%] Meshing curve 1014 (Line)
# Info    : [ 30%] Meshing curve 1015 (Line)
# Info    : [ 30%] Meshing curve 1016 (Line)
# Info    : [ 30%] Meshing curve 1017 (Line)
# Info    : [ 30%] Meshing curve 1018 (Line)
# Info    : [ 40%] Meshing curve 1019 (Line)
# Info    : [ 40%] Meshing curve 1020 (Line)
# Info    : [ 40%] Meshing curve 1021 (Line)
# Info    : [ 40%] Meshing curve 1022 (Line)
# Info    : [ 40%] Meshing curve 1023 (Line)
# Info    : [ 40%] Meshing curve 1024 (Line)
# Info    : [ 40%] Meshing curve 1025 (Line)
# Info    : [ 40%] Meshing curve 1026 (Line)
# Info    : [ 50%] Meshing curve 1027 (Line)
# Info    : [ 50%] Meshing curve 1028 (Line)
# Info    : [ 50%] Meshing curve 1029 (Line)
# Info    : [ 50%] Meshing curve 1030 (Line)
# Info    : [ 50%] Meshing curve 1031 (Line)
# Info    : [ 50%] Meshing curve 1032 (Line)
# Info    : [ 50%] Meshing curve 1033 (Line)
# Info    : [ 50%] Meshing curve 1034 (Line)
# Info    : [ 50%] Meshing curve 1035 (Line)
# Info    : [ 60%] Meshing curve 1036 (Line)
# Info    : [ 60%] Meshing curve 1037 (Line)
# Info    : [ 60%] Meshing curve 1038 (Line)
# Info    : [ 60%] Meshing curve 1039 (Line)
# Info    : [ 60%] Meshing curve 1040 (Line)
# Info    : [ 60%] Meshing curve 1041 (Line)
# Info    : [ 60%] Meshing curve 1042 (Line)
# Info    : [ 60%] Meshing curve 1043 (Line)
# Info    : [ 60%] Meshing curve 1044 (Line)
# Info    : [ 70%] Meshing curve 1045 (Line)
# Info    : [ 70%] Meshing curve 1046 (Line)
# Info    : [ 70%] Meshing curve 1047 (Line)
# Info    : [ 70%] Meshing curve 1048 (Line)
# Info    : [ 70%] Meshing curve 1049 (Line)
# Info    : [ 70%] Meshing curve 1050 (Line)
# Info    : [ 70%] Meshing curve 1051 (Line)
# Info    : [ 70%] Meshing curve 1052 (Line)
# Info    : [ 80%] Meshing curve 1053 (Line)
# Info    : [ 80%] Meshing curve 1054 (Line)
# Info    : [ 80%] Meshing curve 1055 (Line)
# Info    : [ 80%] Meshing curve 1056 (Line)
# Info    : [ 80%] Meshing curve 1057 (Line)
# Info    : [ 80%] Meshing curve 1058 (Line)
# Info    : [ 80%] Meshing curve 1059 (Line)
# Info    : [ 80%] Meshing curve 1060 (Line)
# Info    : [ 80%] Meshing curve 1061 (Line)
# Info    : [ 90%] Meshing curve 1062 (Line)
# Info    : [ 90%] Meshing curve 1063 (Line)
# Info    : [ 90%] Meshing curve 1064 (Line)
# Info    : [ 90%] Meshing curve 1065 (Line)
# Info    : [ 90%] Meshing curve 1066 (Line)
# Info    : [ 90%] Meshing curve 1067 (Line)
# Info    : [ 90%] Meshing curve 1068 (Line)
# Info    : [ 90%] Meshing curve 1069 (Line)
# Info    : [ 90%] Meshing curve 1070 (Line)
# Info    : [100%] Meshing curve 1071 (Line)
# Info    : [100%] Meshing curve 1072 (Line)
# Info    : [100%] Meshing curve 1073 (Line)
# Info    : [100%] Meshing curve 1074 (Line)
# Info    : [100%] Meshing curve 1075 (Line)
# Info    : [100%] Meshing curve 1076 (Line)
# Info    : [100%] Meshing curve 1077 (Line)
# Info    : [100%] Meshing curve 1078 (Line)
# Info    : Done meshing 1D (Wall 0.005497s, CPU 0.006274s)
# Info    : Meshing 2D...
# Info    : Meshing surface 4000000 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0299971s, CPU 0.029905s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 2.1917e-05s, CPU 1.4e-05s)
# Info    : 1482 nodes 2753 elements
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.vtk'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.vtk'
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-2D_rectangle_w_voronoi_inclusions.msh -format msh22 mesh-2D_rectangle_w_voronoi_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:09 2023
# Info    : Reading 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : 181 entities
# Info    : 1176 nodes
# Info    : 1756 elements
# Info    : Done reading 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.000342209s, CPU 0.000297s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 2.4334e-05s, CPU 1.4e-05s)
# Info    : 1188 nodes 1849 elements
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:09 2023 (From start: Wall 0.00927283s, CPU 0.272805s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 1176 vertices
# Found all vertices
# Expecting 1756 cells
# Found all cells
# Conversion done
# Phis0=0.2284211888858091
# Phif0=0.7715788111141909
# [<matplotlib.lines.Line2D at 0x14cdda9e0>,
#  <matplotlib.lines.Line2D at 0x14cddace0>]

# %%
mesh_filename = "mesh-2D_rectangle_w_voronoi_inclusions"
seeds_filename = "seeds-2D_rectangle_w_voronoi_inclusions"

gen.generate_seeds_semi_regular(
    DoI = 0.,
    row = 1,
    domain_y = 1.,
    seeds_filename=seeds_filename)

domain_y = 1.
domain_x = domain_y * math.sqrt(3)/1.5/2 # Cannot be changed!

gen.generate_mesh_2D_rectangle_w_voronoi_inclusions(
    mesh_filename = mesh_filename,
    seeds_filename = seeds_filename,
    h = 0.01,
    lcar = 0.01,
    domain_x = domain_x,
    domain_y = domain_y,
    shift_y = -0.23,
    remove_seeds = False)

mesh = dolfin.Mesh(mesh_filename+".xml")
dolfin.plot(mesh)
# Out:
# [[0.28867513 0.25      ]
#  [0.         0.75      ]
#  [0.8660254  0.25      ]
#  [0.57735027 0.75      ]]
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 122 (Line)
# Info    : [ 10%] Meshing curve 123 (Line)
# Info    : [ 10%] Meshing curve 124 (Line)
# Info    : [ 20%] Meshing curve 148 (Line)
# Info    : [ 20%] Meshing curve 149 (Line)
# Info    : [ 30%] Meshing curve 150 (Line)
# Info    : [ 30%] Meshing curve 151 (Line)
# Info    : [ 30%] Meshing curve 152 (Line)
# Info    : [ 40%] Meshing curve 153 (Line)
# Info    : [ 40%] Meshing curve 154 (Line)
# Info    : [ 50%] Meshing curve 155 (Line)
# Info    : [ 50%] Meshing curve 156 (Line)
# Info    : [ 50%] Meshing curve 157 (Line)
# Info    : [ 60%] Meshing curve 158 (Line)
# Info    : [ 60%] Meshing curve 159 (Line)
# Info    : [ 70%] Meshing curve 160 (Line)
# Info    : [ 70%] Meshing curve 161 (Line)
# Info    : [ 80%] Meshing curve 162 (Line)
# Info    : [ 80%] Meshing curve 163 (Line)
# Info    : [ 80%] Meshing curve 164 (Line)
# Info    : [ 90%] Meshing curve 165 (Line)
# Info    : [ 90%] Meshing curve 166 (Line)
# Info    : [100%] Meshing curve 167 (Line)
# Info    : [100%] Meshing curve 168 (Line)
# Info    : Done meshing 1D (Wall 0.00190246s, CPU 0.002303s)
# Info    : Meshing 2D...
# Info    : Meshing surface 4000000 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0152421s, CPU 0.015219s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 8.54098e-06s, CPU 8e-06s)
# Info    : 1192 nodes 1886 elements
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.vtk'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.vtk'
# /Users/martin/BOULOT/COMPUTATIONAL/Python/micro_poro_structure_generator/micro_poro_structure_generator/generate_mesh_2D_rectangle_w_voronoi_inclusions.py:44: RuntimeWarning: divide by zero encountered in double_scalars
#   m = (Q[1] - P[1])/(Q[0] - P[0])
# /Users/martin/BOULOT/COMPUTATIONAL/Python/micro_poro_structure_generator/micro_poro_structure_generator/generate_mesh_2D_rectangle_w_voronoi_inclusions.py:61: RuntimeWarning: invalid value encountered in double_scalars
#   x = (c2 - c1)/(m1 - m2)
# /Users/martin/BOULOT/COMPUTATIONAL/Python/micro_poro_structure_generator/micro_poro_structure_generator/generate_mesh_2D_rectangle_w_voronoi_inclusions.py:62: RuntimeWarning: invalid value encountered in double_scalars
#   y = (m2*c1 - m1*c2)/(m2 - m1)
# /Users/martin/BOULOT/COMPUTATIONAL/Python/micro_poro_structure_generator/micro_poro_structure_generator/generate_mesh_2D_rectangle_w_voronoi_inclusions.py:45: RuntimeWarning: invalid value encountered in double_scalars
#   c = P[1] - m * P[0]
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-2D_rectangle_w_voronoi_inclusions.msh -format msh22 mesh-2D_rectangle_w_voronoi_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:10 2023
# Info    : Reading 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : 55 entities
# Info    : 670 nodes
# Info    : 870 elements
# Info    : Done reading 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.000321791s, CPU 0.000284s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 3.0125e-05s, CPU 1.3e-05s)
# Info    : 682 nodes 900 elements
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:10 2023 (From start: Wall 0.00592388s, CPU 0.295017s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 670 vertices
# Found all vertices
# Expecting 870 cells
# Found all cells
# Conversion done
# Phis0=0.03434101615137732
# Phif0=0.9656589838486227
# [<matplotlib.lines.Line2D at 0x14ce4de10>,
#  <matplotlib.lines.Line2D at 0x14ce4e110>]

# %%
mesh_filename = "mesh-2D_rectangle_w_voronoi_inclusions"
seeds_filename = "seeds-2D_rectangle_w_voronoi_inclusions"

gen.generate_seeds_semi_regular(
    DoI = 0.3,
    row = 3,
    domain_y = 1.,
    seeds_filename=seeds_filename)

domain_y = 1.
domain_x = domain_y * math.sqrt(3)/1.5 # Cannot be changed!

gen.generate_mesh_2D_rectangle_w_voronoi_inclusions(
    mesh_filename = mesh_filename,
    seeds_filename = seeds_filename,
    h = 0.02,
    lcar = 0.01,
    domain_x = domain_x,
    domain_y = domain_y,
    shift_y = -0.23,
    remove_seeds = False)

mesh = dolfin.Mesh(mesh_filename+".xml")
dolfin.plot(mesh)
# Out:
# [[ 0.12034497  0.08146228]
#  [ 0.01334871  0.22323552]
#  [ 0.26147992  0.08782663]
#  [ 0.21517006  0.25109841]
#  [ 0.4769445   0.10146631]
#  [ 0.37556414  0.22685646]
#  [ 0.69151812  0.06599222]
#  [ 0.55051461  0.25375351]
#  [ 0.84993256  0.09801369]
#  [ 0.75037533  0.25564785]
#  [ 1.04966818  0.06397201]
#  [ 0.97293072  0.22912179]
#  [ 0.07580388  0.40054149]
#  [-0.0091433   0.58818685]
#  [ 0.26532853  0.43618664]
#  [ 0.19588853  0.56628024]
#  [ 0.49139041  0.40699434]
#  [ 0.37955479  0.59517207]
#  [ 0.66144277  0.38845779]
#  [ 0.55644819  0.57573949]
#  [ 0.86607091  0.43561366]
#  [ 0.79439169  0.56155808]
#  [ 1.07574186  0.40797989]
#  [ 0.98494266  0.6022309 ]
#  [ 0.10746462  0.75441911]
#  [ 0.02250403  0.9252499 ]
#  [ 0.26388473  0.77059287]
#  [ 0.20538784  0.91748443]
#  [ 0.4957406   0.7318023 ]
#  [ 0.40111005  0.88967303]
#  [ 0.6819561   0.75171369]
#  [ 0.57276368  0.89683039]
#  [ 0.8819862   0.76894577]
#  [ 0.76546842  0.88922885]
#  [ 1.05180828  0.75530134]
#  [ 0.98315469  0.92280956]]
# Info    : Clearing all models and views...
# Info    : Done clearing all models and views
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 3650 (Line)
# Info    : [ 10%] Meshing curve 3651 (Line)
# Info    : [ 10%] Meshing curve 3652 (Line)
# Info    : [ 10%] Meshing curve 3906 (Line)
# Info    : [ 10%] Meshing curve 3907 (Line)
# Info    : [ 10%] Meshing curve 3908 (Line)
# Info    : [ 10%] Meshing curve 3909 (Line)
# Info    : [ 10%] Meshing curve 3910 (Line)
# Info    : [ 10%] Meshing curve 3911 (Line)
# Info    : [ 10%] Meshing curve 3912 (Line)
# Info    : [ 10%] Meshing curve 3913 (Line)
# Info    : [ 10%] Meshing curve 3914 (Line)
# Info    : [ 10%] Meshing curve 3915 (Line)
# Info    : [ 10%] Meshing curve 3916 (Line)
# Info    : [ 10%] Meshing curve 3917 (Line)
# Info    : [ 10%] Meshing curve 3918 (Line)
# Info    : [ 10%] Meshing curve 3919 (Line)
# Info    : [ 10%] Meshing curve 3920 (Line)
# Info    : [ 10%] Meshing curve 3921 (Line)
# Info    : [ 10%] Meshing curve 3922 (Line)
# Info    : [ 10%] Meshing curve 3923 (Line)
# Info    : [ 10%] Meshing curve 3924 (Line)
# Info    : [ 10%] Meshing curve 3925 (Line)
# Info    : [ 10%] Meshing curve 3926 (Line)
# Info    : [ 10%] Meshing curve 3927 (Line)
# Info    : [ 10%] Meshing curve 3928 (Line)
# Info    : [ 10%] Meshing curve 3929 (Line)
# Info    : [ 20%] Meshing curve 3930 (Line)
# Info    : [ 20%] Meshing curve 3931 (Line)
# Info    : [ 20%] Meshing curve 3932 (Line)
# Info    : [ 20%] Meshing curve 3933 (Line)
# Info    : [ 20%] Meshing curve 3934 (Line)
# Info    : [ 20%] Meshing curve 3935 (Line)
# Info    : [ 20%] Meshing curve 3936 (Line)
# Info    : [ 20%] Meshing curve 3937 (Line)
# Info    : [ 20%] Meshing curve 3938 (Line)
# Info    : [ 20%] Meshing curve 3939 (Line)
# Info    : [ 20%] Meshing curve 3940 (Line)
# Info    : [ 20%] Meshing curve 3941 (Line)
# Info    : [ 20%] Meshing curve 3942 (Line)
# Info    : [ 20%] Meshing curve 3943 (Line)
# Info    : [ 20%] Meshing curve 3944 (Line)
# Info    : [ 20%] Meshing curve 3945 (Line)
# Info    : [ 20%] Meshing curve 3946 (Line)
# Info    : [ 20%] Meshing curve 3947 (Line)
# Info    : [ 20%] Meshing curve 3948 (Line)
# Info    : [ 20%] Meshing curve 3949 (Line)
# Info    : [ 20%] Meshing curve 3950 (Line)
# Info    : [ 20%] Meshing curve 3951 (Line)
# Info    : [ 20%] Meshing curve 3952 (Line)
# Info    : [ 20%] Meshing curve 3953 (Line)
# Info    : [ 20%] Meshing curve 3954 (Line)
# Info    : [ 20%] Meshing curve 3955 (Line)
# Info    : [ 30%] Meshing curve 3956 (Line)
# Info    : [ 30%] Meshing curve 3957 (Line)
# Info    : [ 30%] Meshing curve 3958 (Line)
# Info    : [ 30%] Meshing curve 3959 (Line)
# Info    : [ 30%] Meshing curve 3960 (Line)
# Info    : [ 30%] Meshing curve 3961 (Line)
# Info    : [ 30%] Meshing curve 3962 (Line)
# Info    : [ 30%] Meshing curve 3963 (Line)
# Info    : [ 30%] Meshing curve 3964 (Line)
# Info    : [ 30%] Meshing curve 3965 (Line)
# Info    : [ 30%] Meshing curve 3966 (Line)
# Info    : [ 30%] Meshing curve 3967 (Line)
# Info    : [ 30%] Meshing curve 3968 (Line)
# Info    : [ 30%] Meshing curve 3969 (Line)
# Info    : [ 30%] Meshing curve 3970 (Line)
# Info    : [ 30%] Meshing curve 3971 (Line)
# Info    : [ 30%] Meshing curve 3972 (Line)
# Info    : [ 30%] Meshing curve 3973 (Line)
# Info    : [ 30%] Meshing curve 3974 (Line)
# Info    : [ 30%] Meshing curve 3975 (Line)
# Info    : [ 30%] Meshing curve 3976 (Line)
# Info    : [ 30%] Meshing curve 3977 (Line)
# Info    : [ 30%] Meshing curve 3978 (Line)
# Info    : [ 30%] Meshing curve 3979 (Line)
# Info    : [ 30%] Meshing curve 3980 (Line)
# Info    : [ 30%] Meshing curve 3981 (Line)
# Info    : [ 40%] Meshing curve 3982 (Line)
# Info    : [ 40%] Meshing curve 3983 (Line)
# Info    : [ 40%] Meshing curve 3984 (Line)
# Info    : [ 40%] Meshing curve 3985 (Line)
# Info    : [ 40%] Meshing curve 3986 (Line)
# Info    : [ 40%] Meshing curve 3987 (Line)
# Info    : [ 40%] Meshing curve 3988 (Line)
# Info    : [ 40%] Meshing curve 3989 (Line)
# Info    : [ 40%] Meshing curve 3990 (Line)
# Info    : [ 40%] Meshing curve 3991 (Line)
# Info    : [ 40%] Meshing curve 3992 (Line)
# Info    : [ 40%] Meshing curve 3993 (Line)
# Info    : [ 40%] Meshing curve 3994 (Line)
# Info    : [ 40%] Meshing curve 3995 (Line)
# Info    : [ 40%] Meshing curve 3996 (Line)
# Info    : [ 40%] Meshing curve 3997 (Line)
# Info    : [ 40%] Meshing curve 3998 (Line)
# Info    : [ 40%] Meshing curve 3999 (Line)
# Info    : [ 40%] Meshing curve 4000 (Line)
# Info    : [ 40%] Meshing curve 4001 (Line)
# Info    : [ 40%] Meshing curve 4002 (Line)
# Info    : [ 40%] Meshing curve 4003 (Line)
# Info    : [ 40%] Meshing curve 4004 (Line)
# Info    : [ 40%] Meshing curve 4005 (Line)
# Info    : [ 40%] Meshing curve 4006 (Line)
# Info    : [ 40%] Meshing curve 4007 (Line)
# Info    : [ 50%] Meshing curve 4008 (Line)
# Info    : [ 50%] Meshing curve 4009 (Line)
# Info    : [ 50%] Meshing curve 4010 (Line)
# Info    : [ 50%] Meshing curve 4011 (Line)
# Info    : [ 50%] Meshing curve 4012 (Line)
# Info    : [ 50%] Meshing curve 4013 (Line)
# Info    : [ 50%] Meshing curve 4014 (Line)
# Info    : [ 50%] Meshing curve 4015 (Line)
# Info    : [ 50%] Meshing curve 4016 (Line)
# Info    : [ 50%] Meshing curve 4017 (Line)
# Info    : [ 50%] Meshing curve 4018 (Line)
# Info    : [ 50%] Meshing curve 4019 (Line)
# Info    : [ 50%] Meshing curve 4020 (Line)
# Info    : [ 50%] Meshing curve 4021 (Line)
# Info    : [ 50%] Meshing curve 4022 (Line)
# Info    : [ 50%] Meshing curve 4023 (Line)
# Info    : [ 50%] Meshing curve 4024 (Line)
# Info    : [ 50%] Meshing curve 4025 (Line)
# Info    : [ 50%] Meshing curve 4026 (Line)
# Info    : [ 50%] Meshing curve 4027 (Line)
# Info    : [ 50%] Meshing curve 4028 (Line)
# Info    : [ 50%] Meshing curve 4029 (Line)
# Info    : [ 50%] Meshing curve 4030 (Line)
# Info    : [ 50%] Meshing curve 4031 (Line)
# Info    : [ 50%] Meshing curve 4032 (Line)
# Info    : [ 50%] Meshing curve 4033 (Line)
# Info    : [ 50%] Meshing curve 4034 (Line)
# Info    : [ 60%] Meshing curve 4035 (Line)
# Info    : [ 60%] Meshing curve 4036 (Line)
# Info    : [ 60%] Meshing curve 4037 (Line)
# Info    : [ 60%] Meshing curve 4038 (Line)
# Info    : [ 60%] Meshing curve 4039 (Line)
# Info    : [ 60%] Meshing curve 4040 (Line)
# Info    : [ 60%] Meshing curve 4041 (Line)
# Info    : [ 60%] Meshing curve 4042 (Line)
# Info    : [ 60%] Meshing curve 4043 (Line)
# Info    : [ 60%] Meshing curve 4044 (Line)
# Info    : [ 60%] Meshing curve 4045 (Line)
# Info    : [ 60%] Meshing curve 4046 (Line)
# Info    : [ 60%] Meshing curve 4047 (Line)
# Info    : [ 60%] Meshing curve 4048 (Line)
# Info    : [ 60%] Meshing curve 4049 (Line)
# Info    : [ 60%] Meshing curve 4050 (Line)
# Info    : [ 60%] Meshing curve 4051 (Line)
# Info    : [ 60%] Meshing curve 4052 (Line)
# Info    : [ 60%] Meshing curve 4053 (Line)
# Info    : [ 60%] Meshing curve 4054 (Line)
# Info    : [ 60%] Meshing curve 4055 (Line)
# Info    : [ 60%] Meshing curve 4056 (Line)
# Info    : [ 60%] Meshing curve 4057 (Line)
# Info    : [ 60%] Meshing curve 4058 (Line)
# Info    : [ 60%] Meshing curve 4059 (Line)
# Info    : [ 60%] Meshing curve 4060 (Line)
# Info    : [ 70%] Meshing curve 4061 (Line)
# Info    : [ 70%] Meshing curve 4062 (Line)
# Info    : [ 70%] Meshing curve 4063 (Line)
# Info    : [ 70%] Meshing curve 4064 (Line)
# Info    : [ 70%] Meshing curve 4065 (Line)
# Info    : [ 70%] Meshing curve 4066 (Line)
# Info    : [ 70%] Meshing curve 4067 (Line)
# Info    : [ 70%] Meshing curve 4068 (Line)
# Info    : [ 70%] Meshing curve 4069 (Line)
# Info    : [ 70%] Meshing curve 4070 (Line)
# Info    : [ 70%] Meshing curve 4071 (Line)
# Info    : [ 70%] Meshing curve 4072 (Line)
# Info    : [ 70%] Meshing curve 4073 (Line)
# Info    : [ 70%] Meshing curve 4074 (Line)
# Info    : [ 70%] Meshing curve 4075 (Line)
# Info    : [ 70%] Meshing curve 4076 (Line)
# Info    : [ 70%] Meshing curve 4077 (Line)
# Info    : [ 70%] Meshing curve 4078 (Line)
# Info    : [ 70%] Meshing curve 4079 (Line)
# Info    : [ 70%] Meshing curve 4080 (Line)
# Info    : [ 70%] Meshing curve 4081 (Line)
# Info    : [ 70%] Meshing curve 4082 (Line)
# Info    : [ 70%] Meshing curve 4083 (Line)
# Info    : [ 70%] Meshing curve 4084 (Line)
# Info    : [ 70%] Meshing curve 4085 (Line)
# Info    : [ 70%] Meshing curve 4086 (Line)
# Info    : [ 80%] Meshing curve 4087 (Line)
# Info    : [ 80%] Meshing curve 4088 (Line)
# Info    : [ 80%] Meshing curve 4089 (Line)
# Info    : [ 80%] Meshing curve 4090 (Line)
# Info    : [ 80%] Meshing curve 4091 (Line)
# Info    : [ 80%] Meshing curve 4092 (Line)
# Info    : [ 80%] Meshing curve 4093 (Line)
# Info    : [ 80%] Meshing curve 4094 (Line)
# Info    : [ 80%] Meshing curve 4095 (Line)
# Info    : [ 80%] Meshing curve 4096 (Line)
# Info    : [ 80%] Meshing curve 4097 (Line)
# Info    : [ 80%] Meshing curve 4098 (Line)
# Info    : [ 80%] Meshing curve 4099 (Line)
# Info    : [ 80%] Meshing curve 4100 (Line)
# Info    : [ 80%] Meshing curve 4101 (Line)
# Info    : [ 80%] Meshing curve 4102 (Line)
# Info    : [ 80%] Meshing curve 4103 (Line)
# Info    : [ 80%] Meshing curve 4104 (Line)
# Info    : [ 80%] Meshing curve 4105 (Line)
# Info    : [ 80%] Meshing curve 4106 (Line)
# Info    : [ 80%] Meshing curve 4107 (Line)
# Info    : [ 80%] Meshing curve 4108 (Line)
# Info    : [ 80%] Meshing curve 4109 (Line)
# Info    : [ 80%] Meshing curve 4110 (Line)
# Info    : [ 80%] Meshing curve 4111 (Line)
# Info    : [ 80%] Meshing curve 4112 (Line)
# Info    : [ 90%] Meshing curve 4113 (Line)
# Info    : [ 90%] Meshing curve 4114 (Line)
# Info    : [ 90%] Meshing curve 4115 (Line)
# Info    : [ 90%] Meshing curve 4116 (Line)
# Info    : [ 90%] Meshing curve 4117 (Line)
# Info    : [ 90%] Meshing curve 4118 (Line)
# Info    : [ 90%] Meshing curve 4119 (Line)
# Info    : [ 90%] Meshing curve 4120 (Line)
# Info    : [ 90%] Meshing curve 4121 (Line)
# Info    : [ 90%] Meshing curve 4122 (Line)
# Info    : [ 90%] Meshing curve 4123 (Line)
# Info    : [ 90%] Meshing curve 4124 (Line)
# Info    : [ 90%] Meshing curve 4125 (Line)
# Info    : [ 90%] Meshing curve 4126 (Line)
# Info    : [ 90%] Meshing curve 4127 (Line)
# Info    : [ 90%] Meshing curve 4128 (Line)
# Info    : [ 90%] Meshing curve 4129 (Line)
# Info    : [ 90%] Meshing curve 4130 (Line)
# Info    : [ 90%] Meshing curve 4131 (Line)
# Info    : [ 90%] Meshing curve 4132 (Line)
# Info    : [ 90%] Meshing curve 4133 (Line)
# Info    : [ 90%] Meshing curve 4134 (Line)
# Info    : [ 90%] Meshing curve 4135 (Line)
# Info    : [ 90%] Meshing curve 4136 (Line)
# Info    : [ 90%] Meshing curve 4137 (Line)
# Info    : [ 90%] Meshing curve 4138 (Line)
# Info    : [100%] Meshing curve 4139 (Line)
# Info    : [100%] Meshing curve 4140 (Line)
# Info    : [100%] Meshing curve 4141 (Line)
# Info    : [100%] Meshing curve 4142 (Line)
# Info    : [100%] Meshing curve 4143 (Line)
# Info    : [100%] Meshing curve 4144 (Line)
# Info    : [100%] Meshing curve 4145 (Line)
# Info    : [100%] Meshing curve 4146 (Line)
# Info    : [100%] Meshing curve 4147 (Line)
# Info    : [100%] Meshing curve 4148 (Line)
# Info    : [100%] Meshing curve 4149 (Line)
# Info    : [100%] Meshing curve 4150 (Line)
# Info    : [100%] Meshing curve 4151 (Line)
# Info    : [100%] Meshing curve 4152 (Line)
# Info    : [100%] Meshing curve 4153 (Line)
# Info    : [100%] Meshing curve 4154 (Line)
# Info    : [100%] Meshing curve 4155 (Line)
# Info    : [100%] Meshing curve 4156 (Line)
# Info    : [100%] Meshing curve 4157 (Line)
# Info    : [100%] Meshing curve 4158 (Line)
# Info    : [100%] Meshing curve 4159 (Line)
# Info    : [100%] Meshing curve 4160 (Line)
# Info    : [100%] Meshing curve 4161 (Line)
# Info    : [100%] Meshing curve 4162 (Line)
# Info    : [100%] Meshing curve 4163 (Line)
# Info    : [100%] Meshing curve 4164 (Line)
# Info    : Done meshing 1D (Wall 0.0166621s, CPU 0.018162s)
# Info    : Meshing 2D...
# Info    : Meshing surface 4000000 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.13545s, CPU 0.134315s)
# Info    : Meshing 3D...
# Info    : Done meshing 3D (Wall 9.75002e-06s, CPU 8e-06s)
# Info    : 5261 nodes 10200 elements
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.vtk'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.vtk'
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-2D_rectangle_w_voronoi_inclusions.msh -format msh22 mesh-2D_rectangle_w_voronoi_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:14 2023
# Info    : Reading 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : 529 entities
# Info    : 4625 nodes
# Info    : 6901 elements
# Info    : Done reading 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.000317583s, CPU 0.000285s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 2.3792e-05s, CPU 1.5e-05s)
# Info    : 4635 nodes 7167 elements
# Info    : Writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'...
# Info    : Done writing 'mesh-2D_rectangle_w_voronoi_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:14 2023 (From start: Wall 0.0251518s, CPU 0.304431s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 4625 vertices
# Found all vertices
# Expecting 6901 cells
# Found all cells
# Conversion done
# Phis0=0.1986920276851154
# Phif0=0.8013079723148846
# [<matplotlib.lines.Line2D at 0x14ced0370>,
#  <matplotlib.lines.Line2D at 0x14ced0670>]

# %% [markdown]
# ## 3D

# %% [markdown]
# ### Cube with spherical inclusions

# %%
mesh_filename = "mesh-3D_cube_w_spherical_inclusions"

gen.generate_mesh_3D_cube_w_spherical_inclusions(
    mesh_filename = mesh_filename,
    width = 1.,
    r = 0.3,
    lcar = 0.1)

mesh = dolfin.Mesh(mesh_filename+".xml")
# dolfin.plot(mesh) # Does not work
# Out:
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 11 - 1
# Info    : Setting curve master 39 - 2
# Info    : Setting curve master 40 - 4
# Info    : Setting curve master 21 - 3
# Info    : Setting curve master 27 - 5
# Info    : Setting curve master 41 - 6
# Info    : Setting curve master 37 - 8
# Info    : Setting curve master 33 - 7
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 23 - 14
# Info    : Setting curve master 5 - 1
# Info    : Setting curve master 19 - 13
# Info    : Setting curve master 29 - 15
# Info    : Setting curve master 25 - 9
# Info    : Setting curve master 26 - 10
# Info    : Setting curve master 27 - 11
# Info    : Setting curve master 28 - 12
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 3 - 7
# Info    : Setting curve master 18 - 30
# Info    : Setting curve master 16 - 35
# Info    : Setting curve master 13 - 9
# Info    : Setting curve master 19 - 25
# Info    : Setting curve master 20 - 32
# Info    : Setting curve master 22 - 34
# Info    : Setting curve master 21 - 33
# Info    : Reconstructing periodicity for curve connection 3 - 7
# Info    : Reconstructing periodicity for curve connection 5 - 1
# Info    : Reconstructing periodicity for curve connection 11 - 1
# Info    : Reconstructing periodicity for curve connection 13 - 9
# Info    : Reconstructing periodicity for curve connection 16 - 35
# Info    : Reconstructing periodicity for curve connection 18 - 30
# Info    : Reconstructing periodicity for curve connection 19 - 25
# Info    : Reconstructing periodicity for curve connection 20 - 32
# Info    : Reconstructing periodicity for curve connection 21 - 33
# Info    : Reconstructing periodicity for curve connection 22 - 34
# Info    : Reconstructing periodicity for curve connection 23 - 14
# Info    : Reconstructing periodicity for curve connection 25 - 9
# Info    : Reconstructing periodicity for curve connection 26 - 10
# Info    : Reconstructing periodicity for curve connection 27 - 11
# Info    : Reconstructing periodicity for curve connection 28 - 12
# Info    : Reconstructing periodicity for curve connection 29 - 15
# Info    : Reconstructing periodicity for curve connection 33 - 7
# Info    : Reconstructing periodicity for curve connection 37 - 8
# Info    : Reconstructing periodicity for curve connection 39 - 2
# Info    : Reconstructing periodicity for curve connection 40 - 4
# Info    : Reconstructing periodicity for curve connection 41 - 6
# Info    : Reconstructing periodicity for surface connection 4 - 8
# Info    : Reconstructing periodicity for surface connection 6 - 2
# Info    : Reconstructing periodicity for surface connection 11 - 1
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Circle)
# Info    : [ 10%] Meshing curve 4 (Circle)
# Info    : [ 10%] Meshing curve 5 (Line) as a copy of curve 1
# Info    : [ 20%] Meshing curve 6 (Circle)
# Info    : [ 20%] Meshing curve 7 (Line)
# Info    : [ 20%] Meshing curve 8 (Circle)
# Info    : [ 20%] Meshing curve 9 (Line)
# Info    : [ 30%] Meshing curve 10 (Circle)
# Info    : [ 30%] Meshing curve 11 (Line) as a copy of curve 1
# Info    : [ 30%] Meshing curve 12 (Circle)
# Info    : [ 30%] Meshing curve 13 (Line) as a copy of curve 9
# Info    : [ 30%] Meshing curve 14 (Circle)
# Info    : [ 40%] Meshing curve 15 (Circle)
# Info    : [ 50%] Meshing curve 23 (Circle) as a copy of curve 14
# Info    : [ 60%] Meshing curve 25 (Line) as a copy of curve 9
# Info    : [ 60%] Meshing curve 26 (Circle) as a copy of curve 10
# Info    : [ 60%] Meshing curve 27 (Line) as a copy of curve 11
# Info    : [ 70%] Meshing curve 28 (Circle) as a copy of curve 12
# Info    : [ 70%] Meshing curve 29 (Circle) as a copy of curve 15
# Info    : [ 70%] Meshing curve 30 (Circle)
# Info    : [ 80%] Meshing curve 32 (Circle)
# Info    : [ 80%] Meshing curve 33 (Line) as a copy of curve 7
# Info    : [ 80%] Meshing curve 34 (Circle)
# Info    : [ 80%] Meshing curve 35 (Circle)
# Info    : [ 90%] Meshing curve 37 (Circle) as a copy of curve 8
# Info    : [ 90%] Meshing curve 39 (Circle) as a copy of curve 2
# Info    : [ 90%] Meshing curve 40 (Circle) as a copy of curve 4
# Info    : [100%] Meshing curve 41 (Circle) as a copy of curve 6
# Info    : [100%] Meshing curve 3 (Line) as a copy of curve 7
# Info    : [100%] Meshing curve 16 (Circle) as a copy of curve 35
# Info    : [100%] Meshing curve 18 (Circle) as a copy of curve 30
# Info    : [100%] Meshing curve 19 (Line) as a copy of curve 25
# Info    : [100%] Meshing curve 20 (Circle) as a copy of curve 32
# Info    : [100%] Meshing curve 21 (Line) as a copy of curve 33
# Info    : [100%] Meshing curve 22 (Circle) as a copy of curve 34
# Info    : Done meshing 1D (Wall 0.00158892s, CPU 0.001773s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 3 (Sphere, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 5 (Sphere, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 6 (Plane) as a copy of surface 2
# Info    : [ 50%] Meshing surface 7 (Sphere, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 9 (Sphere, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 10 (Sphere, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 11 (Plane) as a copy of surface 1
# Info    : [ 80%] Meshing surface 12 (Sphere, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 13 (Sphere, Frontal-Delaunay)
# Info    : [100%] Meshing surface 14 (Sphere, Frontal-Delaunay)
# Info    : [100%] Meshing surface 4 (Plane) as a copy of surface 8
# Info    : Done meshing 2D (Wall 0.0237179s, CPU 0.024177s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 779 nodes...
# Info    : Done tetrahedrizing 787 nodes (Wall 0.00510504s, CPU 0.005036s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0116608s, CPU 0.011597s)
# Info    : Found volume 10
# Info    : It. 0 - 0 nodes created - worst tet radius 5.21333 (nodes removed 0 0)
# Info    : 3D refinement terminated (1208 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 4986 tetrahedra created in 0.0183177 sec. (272195 tets/s)
# Info    : Done meshing 3D (Wall 0.0438887s, CPU 0.043641s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 10
# Info    : Optimization starts (volume = 0.890502) with worst = 0.0345241 / average = 0.755777:
# Info    : 0.00 < quality < 0.10 :        11 elements
# Info    : 0.10 < quality < 0.20 :        26 elements
# Info    : 0.20 < quality < 0.30 :        60 elements
# Info    : 0.30 < quality < 0.40 :        86 elements
# Info    : 0.40 < quality < 0.50 :       174 elements
# Info    : 0.50 < quality < 0.60 :       323 elements
# Info    : 0.60 < quality < 0.70 :       737 elements
# Info    : 0.70 < quality < 0.80 :      1251 elements
# Info    : 0.80 < quality < 0.90 :      1552 elements
# Info    : 0.90 < quality < 1.00 :       766 elements
# Info    : 94 edge swaps, 2 node relocations (volume = 0.890502): worst = 0.225043 / average = 0.767401 (Wall 0.00223325s, CPU 0.0022s)
# Info    : 95 edge swaps, 2 node relocations (volume = 0.890502): worst = 0.30172 / average = 0.767543 (Wall 0.00246967s, CPU 0.00246s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        84 elements
# Info    : 0.40 < quality < 0.50 :       163 elements
# Info    : 0.50 < quality < 0.60 :       331 elements
# Info    : 0.60 < quality < 0.70 :       733 elements
# Info    : 0.70 < quality < 0.80 :      1257 elements
# Info    : 0.80 < quality < 0.90 :      1566 elements
# Info    : 0.90 < quality < 1.00 :       766 elements
# Info    : Done optimizing mesh (Wall 0.00565438s, CPU 0.005655s)
# Info    : Reconstructing periodicity for curve connection 3 - 7
# Info    : Reconstructing periodicity for curve connection 5 - 1
# Info    : Reconstructing periodicity for curve connection 11 - 1
# Info    : Reconstructing periodicity for curve connection 13 - 9
# Info    : Reconstructing periodicity for curve connection 16 - 35
# Info    : Reconstructing periodicity for curve connection 18 - 30
# Info    : Reconstructing periodicity for curve connection 19 - 25
# Info    : Reconstructing periodicity for curve connection 20 - 32
# Info    : Reconstructing periodicity for curve connection 21 - 33
# Info    : Reconstructing periodicity for curve connection 22 - 34
# Info    : Reconstructing periodicity for curve connection 23 - 14
# Info    : Reconstructing periodicity for curve connection 25 - 9
# Info    : Reconstructing periodicity for curve connection 26 - 10
# Info    : Reconstructing periodicity for curve connection 27 - 11
# Info    : Reconstructing periodicity for curve connection 28 - 12
# Info    : Reconstructing periodicity for curve connection 29 - 15
# Info    : Reconstructing periodicity for curve connection 33 - 7
# Info    : Reconstructing periodicity for curve connection 37 - 8
# Info    : Reconstructing periodicity for curve connection 39 - 2
# Info    : Reconstructing periodicity for curve connection 40 - 4
# Info    : Reconstructing periodicity for curve connection 41 - 6
# Info    : Reconstructing periodicity for surface connection 4 - 8
# Info    : Reconstructing periodicity for surface connection 6 - 2
# Info    : Reconstructing periodicity for surface connection 11 - 1
# Info    : 1208 nodes 6646 elements
# Info    : Writing 'mesh-3D_cube_w_spherical_inclusions.msh'...
# Info    : Done writing 'mesh-3D_cube_w_spherical_inclusions.msh'
# Info    : Running '/opt/miniconda3/envs/fenics-2019-py310/bin/gmsh -2 -o mesh-3D_cube_w_spherical_inclusions.msh -format msh22 mesh-3D_cube_w_spherical_inclusions.msh' [Gmsh 4.11.1, 1 node, max. 1 thread]
# Info    : Started on Thu Nov 23 15:21:15 2023
# Info    : Reading 'mesh-3D_cube_w_spherical_inclusions.msh'...
# Info    : 83 entities
# Info    : 1208 nodes
# Info    : 4900 elements
# Info    : Done reading 'mesh-3D_cube_w_spherical_inclusions.msh'
# Info    : Meshing 1D...
# Info    : Done meshing 1D (Wall 0.000295042s, CPU 0.000264s)
# Info    : Meshing 2D...
# Info    : Done meshing 2D (Wall 4.125e-05s, CPU 2.7e-05s)
# Info    : Optimizing mesh...
# Info    : Done optimizing mesh (Wall 0.000134167s, CPU 0.000129s)
# Info    : 1208 nodes 4924 elements
# Info    : Writing 'mesh-3D_cube_w_spherical_inclusions.msh'...
# Info    : Done writing 'mesh-3D_cube_w_spherical_inclusions.msh'
# Info    : Stopped on Thu Nov 23 15:21:15 2023 (From start: Wall 0.0167332s, CPU 0.294714s)
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 1208 vertices
# Found all vertices
# Expecting 4900 cells
# Found all cells
# Conversion done
# Info    : Writing 'mesh-3D_cube_w_spherical_inclusions.vtk'...
# Info    : Done writing 'mesh-3D_cube_w_spherical_inclusions.vtk'
# porosity:0.11309733552923253

# %% [markdown]
# ## Cleaning

# %%
os.system("rm -rf mesh-*")
os.system("rm -rf seeds-*")
# Out:
# 0
